# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import matplotlib.pyplot as plt
import numpy as np
import os
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

class SkinCancerModel:
    def __init__(self, img_size=(224, 224), batch_size=32):
        self.img_size = img_size
        self.batch_size = batch_size
        self.model = None
        self.history = None
        
    def create_model(self):
        """Crear el modelo CNN para clasificación de melanomas"""
        model = Sequential([
            # Primer bloque convolucional
            Conv2D(32, (3, 3), activation='relu', input_shape=(*self.img_size, 3)),
            BatchNormalization(),
            MaxPooling2D(2, 2),
            
            # Segundo bloque convolucional
            Conv2D(64, (3, 3), activation='relu'),
            BatchNormalization(),
            MaxPooling2D(2, 2),
            
            # Tercer bloque convolucional
            Conv2D(128, (3, 3), activation='relu'),
            BatchNormalization(),
            MaxPooling2D(2, 2),
            
            # Cuarto bloque convolucional
            Conv2D(256, (3, 3), activation='relu'),
            BatchNormalization(),
            MaxPooling2D(2, 2),
            
            # Quinto bloque convolucional
            Conv2D(512, (3, 3), activation='relu'),
            BatchNormalization(),
            MaxPooling2D(2, 2),
            
            # Capa de aplanamiento
            Flatten(),
            
            # Capas densas con dropout
            Dense(512, activation='relu'),
            Dropout(0.5),
            Dense(256, activation='relu'),
            Dropout(0.5),
            Dense(128, activation='relu'),
            Dropout(0.3),
            
            # Capa de salida (clasificación binaria)
            Dense(1, activation='sigmoid')
        ])
        
        model.compile(
            optimizer=Adam(learning_rate=0.0001),
            loss='binary_crossentropy',
            metrics=['accuracy']
        )
        
        self.model = model
        return model
    
    def create_data_generators(self, train_dir, test_dir):
        """Crear generadores de datos con data augmentation"""
        # Generador para entrenamiento con data augmentation
        train_datagen = ImageDataGenerator(
            rescale=1./255,
            rotation_range=20,
            width_shift_range=0.2,
            height_shift_range=0.2,
            horizontal_flip=True,
            zoom_range=0.2,
            shear_range=0.2,
            fill_mode='nearest',
            validation_split=0.2  # 20% para validación
        )
        
        # Generador para test sin augmentation
        test_datagen = ImageDataGenerator(rescale=1./255)
        
        # Crear generadores
        train_generator = train_datagen.flow_from_directory(
            train_dir,
            target_size=self.img_size,
            batch_size=self.batch_size,
            class_mode='binary',
            subset='training'
        )
        
        val_generator = train_datagen.flow_from_directory(
            train_dir,
            target_size=self.img_size,
            batch_size=self.batch_size,
            class_mode='binary',
            subset='validation'
        )
        
        test_generator = test_datagen.flow_from_directory(
            test_dir,
            target_size=self.img_size,
            batch_size=self.batch_size,
            class_mode='binary',
            shuffle=False
        )
        
        return train_generator, val_generator, test_generator
    
    def train_model(self, train_generator, val_generator, epochs=50):
        """Entrenar el modelo"""
        if self.model is None:
            self.create_model()
        
        # Callbacks
        callbacks = [
            EarlyStopping(
                monitor='val_loss',
                patience=10,
                restore_best_weights=True,
                verbose=1
            ),
            ReduceLROnPlateau(
                monitor='val_loss',
                factor=0.5,
                patience=5,
                min_lr=1e-7,
                verbose=1
            ),
            ModelCheckpoint(
                'best_model.h5',
                monitor='val_accuracy',
                save_best_only=True,
                verbose=1
            )
        ]
        
        # Entrenar el modelo
        self.history = self.model.fit(
            train_generator,
            epochs=epochs,
            validation_data=val_generator,
            callbacks=callbacks,
            verbose=1
        )
        
        return self.history
    
    def evaluate_model(self, test_generator):
        """Evaluar el modelo en el conjunto de test"""
        # Predicciones
        predictions = self.model.predict(test_generator)
        predicted_classes = (predictions > 0.5).astype(int)
        
        # Clases reales
        true_classes = test_generator.classes
        
        # Métricas
        print("\n=== EVALUACIÓN DEL MODELO ===")
        print(f"Accuracy en test: {np.mean(predicted_classes.flatten() == true_classes):.4f}")
        
        # Reporte de clasificación
        print("\n=== REPORTE DE CLASIFICACIÓN ===")
        print(classification_report(true_classes, predicted_classes.flatten(), 
                                  target_names=['Benigno', 'Maligno']))
        
        # Matriz de confusión
        cm = confusion_matrix(true_classes, predicted_classes.flatten())
        plt.figure(figsize=(8, 6))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                   xticklabels=['Benigno', 'Maligno'], 
                   yticklabels=['Benigno', 'Maligno'])
        plt.title('Matriz de Confusión')
        plt.ylabel('Valor Real')
        plt.xlabel('Predicción')
        plt.show()
        
        return predicted_classes, true_classes
    
    def plot_training_history(self):
        """Graficar el historial de entrenamiento"""
        if self.history is None:
            print("No hay historial de entrenamiento disponible")
            return
        
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
        
        # Accuracy
        ax1.plot(self.history.history['accuracy'], label='Train Accuracy')
        ax1.plot(self.history.history['val_accuracy'], label='Val Accuracy')
        ax1.set_title('Accuracy del Modelo')
        ax1.set_xlabel('Época')
        ax1.set_ylabel('Accuracy')
        ax1.legend()
        ax1.grid(True)
        
        # Loss
        ax2.plot(self.history.history['loss'], label='Train Loss')
        ax2.plot(self.history.history['val_loss'], label='Val Loss')
        ax2.set_title('Loss del Modelo')
        ax2.set_xlabel('Época')
        ax2.set_ylabel('Loss')
        ax2.legend()
        ax2.grid(True)
        
        plt.tight_layout()
        plt.show()
    
    def save_model(self, filepath='skin_cancer_model.h5'):
        """Guardar el modelo entrenado"""
        if self.model is not None:
            self.model.save(filepath)
            print(f"Modelo guardado en: {filepath}")
        else:
            print("No hay modelo para guardar")

# Función principal de entrenamiento
def main():
    # Configurar rutas (ajustar según tu estructura de carpetas)
    train_dir = 'melanoma_cancer_dataset/train'  # Carpeta con 3000 imágenes benignas y 3000 malignas
    test_dir = 'melanoma_cancer_dataset/test'    # Carpeta con 500 imágenes benignas y 500 malignas
    
    # Crear instancia del modelo
    skin_model = SkinCancerModel(img_size=(224, 224), batch_size=32)
    
    # Crear generadores de datos
    print("Creando generadores de datos...")
    train_gen, val_gen, test_gen = skin_model.create_data_generators(train_dir, test_dir)
    
    # Crear y mostrar el modelo
    print("Creando modelo...")
    model = skin_model.create_model()
    print(model.summary())
    
    # Entrenar el modelo
    print("Iniciando entrenamiento...")
    history = skin_model.train_model(train_gen, val_gen, epochs=50)
    
    # Mostrar gráficos de entrenamiento
    skin_model.plot_training_history()
    
    # Evaluar el modelo
    print("Evaluando modelo...")
    skin_model.evaluate_model(test_gen)
    
    # Guardar el modelo
    skin_model.save_model('skin_cancer_model.h5')
    
    print("\n¡Entrenamiento completado!")

if __name__ == "__main__":
    main()
# Out:
# Creando generadores de datos...
# Found 4800 images belonging to 2 classes.
# Found 1200 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.
# Creando modelo...
# C:\Users\daclv\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 222, 222, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 222, 222, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 111, 111, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 109, 109, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 109, 109, 64)        │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 54, 54, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 52, 52, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 52, 52, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 26, 26, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 24, 24, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 24, 24, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 12, 12, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 10, 10, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 10, 10, 512)         │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 5, 5, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 12800)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │       6,554,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 8,291,009 (31.63 MB)
#  Trainable params: 8,289,025 (31.62 MB)
#  Non-trainable params: 1,984 (7.75 KB)
# None
# Iniciando entrenamiento...
# C:\Users\daclv\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7575 - loss: 0.7211
# Epoch 1: val_accuracy improved from -inf to 0.50000, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 242s 2s/step - accuracy: 0.7578 - loss: 0.7202 - val_accuracy: 0.5000 - val_loss: 2.0822 - learning_rate: 1.0000e-04
# Epoch 2/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8452 - loss: 0.4099
# Epoch 2: val_accuracy improved from 0.50000 to 0.50167, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 236s 2s/step - accuracy: 0.8452 - loss: 0.4098 - val_accuracy: 0.5017 - val_loss: 1.2621 - learning_rate: 1.0000e-04
# Epoch 3/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8535 - loss: 0.3890
# Epoch 3: val_accuracy improved from 0.50167 to 0.79750, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 230s 2s/step - accuracy: 0.8535 - loss: 0.3890 - val_accuracy: 0.7975 - val_loss: 0.4683 - learning_rate: 1.0000e-04
# Epoch 4/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8736 - loss: 0.3296
# Epoch 4: val_accuracy improved from 0.79750 to 0.88500, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 237s 2s/step - accuracy: 0.8736 - loss: 0.3296 - val_accuracy: 0.8850 - val_loss: 0.3103 - learning_rate: 1.0000e-04
# Epoch 5/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8692 - loss: 0.3366
# Epoch 5: val_accuracy did not improve from 0.88500
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 236s 2s/step - accuracy: 0.8692 - loss: 0.3365 - val_accuracy: 0.8725 - val_loss: 0.3227 - learning_rate: 1.0000e-04
# Epoch 6/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8809 - loss: 0.3018
# Epoch 6: val_accuracy improved from 0.88500 to 0.88917, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 237s 2s/step - accuracy: 0.8809 - loss: 0.3018 - val_accuracy: 0.8892 - val_loss: 0.3067 - learning_rate: 1.0000e-04
# Epoch 7/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8764 - loss: 0.3117
# Epoch 7: val_accuracy did not improve from 0.88917
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 233s 2s/step - accuracy: 0.8764 - loss: 0.3116 - val_accuracy: 0.8742 - val_loss: 0.3295 - learning_rate: 1.0000e-04
# Epoch 8/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8944 - loss: 0.2951
# Epoch 8: val_accuracy improved from 0.88917 to 0.89333, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 239s 2s/step - accuracy: 0.8943 - loss: 0.2952 - val_accuracy: 0.8933 - val_loss: 0.2938 - learning_rate: 1.0000e-04
# Epoch 9/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8815 - loss: 0.2890
# Epoch 9: val_accuracy did not improve from 0.89333
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 232s 2s/step - accuracy: 0.8815 - loss: 0.2890 - val_accuracy: 0.8842 - val_loss: 0.3351 - learning_rate: 1.0000e-04
# Epoch 10/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8923 - loss: 0.2680
# Epoch 10: val_accuracy improved from 0.89333 to 0.90333, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 227s 2s/step - accuracy: 0.8923 - loss: 0.2680 - val_accuracy: 0.9033 - val_loss: 0.2822 - learning_rate: 1.0000e-04
# Epoch 11/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9034 - loss: 0.2500
# Epoch 11: val_accuracy did not improve from 0.90333
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 232s 2s/step - accuracy: 0.9034 - loss: 0.2500 - val_accuracy: 0.8917 - val_loss: 0.2992 - learning_rate: 1.0000e-04
# Epoch 12/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9065 - loss: 0.2293
# Epoch 12: val_accuracy did not improve from 0.90333
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 231s 2s/step - accuracy: 0.9065 - loss: 0.2294 - val_accuracy: 0.8792 - val_loss: 0.3257 - learning_rate: 1.0000e-04
# Epoch 13/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8936 - loss: 0.2642
# Epoch 13: val_accuracy did not improve from 0.90333
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 231s 2s/step - accuracy: 0.8936 - loss: 0.2642 - val_accuracy: 0.8817 - val_loss: 0.2875 - learning_rate: 1.0000e-04
# Epoch 14/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9042 - loss: 0.2238
# Epoch 14: val_accuracy did not improve from 0.90333
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 231s 2s/step - accuracy: 0.9042 - loss: 0.2238 - val_accuracy: 0.8567 - val_loss: 0.3635 - learning_rate: 1.0000e-04
# Epoch 15/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9008 - loss: 0.2337
# Epoch 15: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 15: val_accuracy did not improve from 0.90333
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 234s 2s/step - accuracy: 0.9008 - loss: 0.2338 - val_accuracy: 0.8717 - val_loss: 0.3271 - learning_rate: 1.0000e-04
# Epoch 16/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9115 - loss: 0.2277
# Epoch 16: val_accuracy did not improve from 0.90333
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 236s 2s/step - accuracy: 0.9115 - loss: 0.2276 - val_accuracy: 0.8992 - val_loss: 0.2679 - learning_rate: 5.0000e-05
# Epoch 17/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9192 - loss: 0.1990
# Epoch 17: val_accuracy did not improve from 0.90333
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 243s 2s/step - accuracy: 0.9192 - loss: 0.1990 - val_accuracy: 0.9000 - val_loss: 0.2908 - learning_rate: 5.0000e-05
# Epoch 18/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9214 - loss: 0.2089
# Epoch 18: val_accuracy did not improve from 0.90333
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 236s 2s/step - accuracy: 0.9214 - loss: 0.2090 - val_accuracy: 0.9033 - val_loss: 0.2682 - learning_rate: 5.0000e-05
# Epoch 19/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9184 - loss: 0.2187
# Epoch 19: val_accuracy improved from 0.90333 to 0.90417, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 240s 2s/step - accuracy: 0.9184 - loss: 0.2186 - val_accuracy: 0.9042 - val_loss: 0.2659 - learning_rate: 5.0000e-05
# Epoch 20/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9163 - loss: 0.2097
# Epoch 20: val_accuracy did not improve from 0.90417
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 233s 2s/step - accuracy: 0.9163 - loss: 0.2097 - val_accuracy: 0.8975 - val_loss: 0.2775 - learning_rate: 5.0000e-05
# Epoch 21/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9281 - loss: 0.1825
# Epoch 21: val_accuracy did not improve from 0.90417
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 232s 2s/step - accuracy: 0.9281 - loss: 0.1826 - val_accuracy: 0.9008 - val_loss: 0.2793 - learning_rate: 5.0000e-05
# Epoch 22/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9343 - loss: 0.1832
# Epoch 22: val_accuracy did not improve from 0.90417
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 238s 2s/step - accuracy: 0.9342 - loss: 0.1833 - val_accuracy: 0.9033 - val_loss: 0.2756 - learning_rate: 5.0000e-05
# Epoch 23/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9215 - loss: 0.2034
# Epoch 23: val_accuracy improved from 0.90417 to 0.90667, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 238s 2s/step - accuracy: 0.9215 - loss: 0.2033 - val_accuracy: 0.9067 - val_loss: 0.2518 - learning_rate: 5.0000e-05
# Epoch 24/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9319 - loss: 0.1770
# Epoch 24: val_accuracy did not improve from 0.90667
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 223s 1s/step - accuracy: 0.9319 - loss: 0.1770 - val_accuracy: 0.8417 - val_loss: 0.3415 - learning_rate: 5.0000e-05
# Epoch 25/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9302 - loss: 0.1894
# Epoch 25: val_accuracy did not improve from 0.90667
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 236s 2s/step - accuracy: 0.9302 - loss: 0.1894 - val_accuracy: 0.8792 - val_loss: 0.2915 - learning_rate: 5.0000e-05
# Epoch 26/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9319 - loss: 0.1844
# Epoch 26: val_accuracy improved from 0.90667 to 0.92000, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 233s 2s/step - accuracy: 0.9319 - loss: 0.1845 - val_accuracy: 0.9200 - val_loss: 0.2416 - learning_rate: 5.0000e-05
# Epoch 27/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9262 - loss: 0.1912
# Epoch 27: val_accuracy did not improve from 0.92000
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 233s 2s/step - accuracy: 0.9262 - loss: 0.1912 - val_accuracy: 0.8725 - val_loss: 0.3212 - learning_rate: 5.0000e-05
# Epoch 28/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9317 - loss: 0.1764
# Epoch 28: val_accuracy did not improve from 0.92000
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 226s 2s/step - accuracy: 0.9317 - loss: 0.1764 - val_accuracy: 0.9067 - val_loss: 0.2689 - learning_rate: 5.0000e-05
# Epoch 29/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9258 - loss: 0.1884
# Epoch 29: val_accuracy did not improve from 0.92000
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 226s 2s/step - accuracy: 0.9258 - loss: 0.1884 - val_accuracy: 0.9125 - val_loss: 0.2523 - learning_rate: 5.0000e-05
# Epoch 30/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9286 - loss: 0.1888
# Epoch 30: val_accuracy did not improve from 0.92000
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 223s 1s/step - accuracy: 0.9286 - loss: 0.1888 - val_accuracy: 0.9050 - val_loss: 0.2742 - learning_rate: 5.0000e-05
# Epoch 31/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9339 - loss: 0.1821
# Epoch 31: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 31: val_accuracy did not improve from 0.92000
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 232s 2s/step - accuracy: 0.9339 - loss: 0.1821 - val_accuracy: 0.9125 - val_loss: 0.2585 - learning_rate: 5.0000e-05
# Epoch 32/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9321 - loss: 0.1694
# Epoch 32: val_accuracy did not improve from 0.92000
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 223s 1s/step - accuracy: 0.9321 - loss: 0.1694 - val_accuracy: 0.8975 - val_loss: 0.2573 - learning_rate: 2.5000e-05
# Epoch 33/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9303 - loss: 0.1846
# Epoch 33: val_accuracy did not improve from 0.92000
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 226s 2s/step - accuracy: 0.9303 - loss: 0.1845 - val_accuracy: 0.8992 - val_loss: 0.2729 - learning_rate: 2.5000e-05
# Epoch 34/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9358 - loss: 0.1674
# Epoch 34: val_accuracy did not improve from 0.92000
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 237s 2s/step - accuracy: 0.9358 - loss: 0.1674 - val_accuracy: 0.8983 - val_loss: 0.2583 - learning_rate: 2.5000e-05
# Epoch 35/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9412 - loss: 0.1598
# Epoch 35: val_accuracy did not improve from 0.92000
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 232s 2s/step - accuracy: 0.9412 - loss: 0.1598 - val_accuracy: 0.9042 - val_loss: 0.2549 - learning_rate: 2.5000e-05
# Epoch 36/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9415 - loss: 0.1573
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 36: val_accuracy did not improve from 0.92000
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 226s 2s/step - accuracy: 0.9415 - loss: 0.1573 - val_accuracy: 0.9033 - val_loss: 0.2484 - learning_rate: 2.5000e-05
# Epoch 36: early stopping
# Restoring model weights from the end of the best epoch: 26.
# Evaluando modelo...
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 261ms/step
#
# === EVALUACIÓN DEL MODELO ===
# Accuracy en test: 0.9110
#
# === REPORTE DE CLASIFICACIÓN ===
#               precision    recall  f1-score   support
#
#      Benigno       0.88      0.95      0.91       500
#      Maligno       0.94      0.88      0.91       500
#
#     accuracy                           0.91      1000
#    macro avg       0.91      0.91      0.91      1000
# weighted avg       0.91      0.91      0.91      1000
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Modelo guardado en: skin_cancer_model.h5
#
# ¡Entrenamiento completado!
